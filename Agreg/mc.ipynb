# %%
import numpy.random as rd


emin=1.3
emax=1.5
N=10000
e=rd.uniform(emin,emax,N)

e
# Out:
# array([1.45746038, 1.41636747, 1.30403312, ..., 1.40254378, 1.49548705,
#        1.3585015 ])

# %% [markdown]
# Voilà la question 2, à vous maintenant :

# %%
import numpy as np

eps0=8.8e-12
L=2e-3
R=3e-2
S=3.14*R**2

f=1/(2*3.14)*np.sqrt(e/(L*eps0*S))

plt.hist(f)
# Out:
# (array([ 948.,  961.,  974., 1030., 1089.,  982., 1043.,  959.,  972.,
#         1042.]),
#  array([25743675.8133708 , 25934608.88960637, 26125541.96584194,
#         26316475.04207751, 26507408.11831309, 26698341.19454866,
#         26889274.27078423, 27080207.3470198 , 27271140.42325537,
#         27462073.49949094, 27653006.57572651]),
#  <BarContainer object of 10 artists>)

# %%
x1=5e-2
u1=0.14e-2
x2=15e-2
u2=0.12e-2

x1_simu=rd.uniform(x1-u1,x1+u1,10000)
x2_simu=rd.uniform(x2-u2,x2+u2,10000)

l_simu=x2_simu-x1_simu

plt.hist(x1_simu)
plt.hist(x2_simu)

plt.hist(l_simu)
# Out:
# (array([ 258.,  624., 1059., 1445., 1750., 1686., 1386.,  980.,  595.,
#          217.]),
#  array([0.09745114, 0.09796338, 0.09847562, 0.09898786, 0.0995001 ,
#         0.10001234, 0.10052458, 0.10103682, 0.10154906, 0.10206129,
#         0.10257353]),
#  <BarContainer object of 10 artists>)

# %%
np.std(l_simu)
# Out:
# 0.0018427092985646753
